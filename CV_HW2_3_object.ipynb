# %%
import cv2
import numpy as np
from skimage import io
from matplotlib import pyplot as plt
from google.colab.patches import cv2_imshow

def url_to_image(url):
  print("downloading %s" % (url))
  return cv2.cvtColor(io.imread(url), cv2.COLOR_BGR2RGB)

# %%
urls = [f"https://raw.githubusercontent.com/mdavydov/ComputerVisionCourse/master/tasks/object/obj{i+1}.jpg" for i in range(6)]
# url = "https://raw.githubusercontent.com/mdavydov/ComputerVisionCourse/master/tasks/text/text1.jpg"
images, images_gray = [], []

for url in urls:
  img = url_to_image(url)
  images.append(img)
  grayscaled = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
  images_gray.append(grayscaled)
  cv2_imshow(grayscaled)
# Out:
# downloading https://raw.githubusercontent.com/mdavydov/ComputerVisionCourse/master/tasks/object/obj1.jpg
# <PIL.Image.Image image mode=L size=480x269 at 0x7F434C98E518>
# downloading https://raw.githubusercontent.com/mdavydov/ComputerVisionCourse/master/tasks/object/obj2.jpg
# <PIL.Image.Image image mode=L size=480x320 at 0x7F434A868B00>
# downloading https://raw.githubusercontent.com/mdavydov/ComputerVisionCourse/master/tasks/object/obj3.jpg
# <PIL.Image.Image image mode=L size=480x376 at 0x7F434A877A20>
# downloading https://raw.githubusercontent.com/mdavydov/ComputerVisionCourse/master/tasks/object/obj4.jpg
# <PIL.Image.Image image mode=L size=480x319 at 0x7F434A866E48>
# downloading https://raw.githubusercontent.com/mdavydov/ComputerVisionCourse/master/tasks/object/obj5.jpg
# <PIL.Image.Image image mode=L size=480x320 at 0x7F434A87A4A8>
# downloading https://raw.githubusercontent.com/mdavydov/ComputerVisionCourse/master/tasks/object/obj6.jpg
# <PIL.Image.Image image mode=L size=319x480 at 0x7F434C98E518>

# %% [markdown]
# # IMAGE 1

# %%
img = images[0].copy()

cv2.rectangle(img, (40,30), (450,240), (255, 0, 0), 2)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=480x269 at 0x7F434C148160>

# %%
mask = np.zeros(img.shape[:2],np.uint8)

bgdModel = np.zeros((1,65),np.float64)

fgdModel = np.zeros((1,65),np.float64)

rect = (40,30,450,240)
cv2.grabCut(img,mask,rect,bgdModel,fgdModel,5,cv2.GC_INIT_WITH_RECT)

mask2 = np.where((mask==2)|(mask==0),0,1).astype('uint8')
img1 = img*mask2[:,:,np.newaxis]
cv2_imshow(img1)
# Out:
# <PIL.Image.Image image mode=RGB size=480x269 at 0x7F434A88F208>

# %% [markdown]
# # IMAGE 2 (Need FIX)

# %%
img = images[1].copy()

cv2.rectangle(img, (110, 80), (430, 275), (255, 0, 0), 2)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=480x320 at 0x7F434C148780>

# %%
img = images[1].copy()
mask = np.zeros(img.shape[:2],np.uint8)

bgdModel = np.zeros((1,65),np.float64)

fgdModel = np.zeros((1,65),np.float64)

rect = (110, 80, 430, 275)
cv2.grabCut(img,mask,rect,bgdModel,fgdModel,5,cv2.GC_INIT_WITH_RECT)

mask2 = np.where((mask==2)|(mask==0),0,1).astype('uint8')
img1 = img*mask2[:,:,np.newaxis]
cv2_imshow(img1)
# Out:
# <PIL.Image.Image image mode=RGB size=480x320 at 0x7F434A8765C0>

# %% [markdown]
# # IMAGE 3

# %%
img = images[2].copy()

cv2.rectangle(img, (70, 50), (250, 210), (255, 0, 0), 2)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=480x376 at 0x7F434C148748>

# %%
img = images[2].copy()
mask = np.zeros(img.shape[:2],np.uint8)

bgdModel = np.zeros((1,65),np.float64)

fgdModel = np.zeros((1,65),np.float64)

rect = (70, 50, 250, 210)
cv2.grabCut(img,mask,rect,bgdModel,fgdModel,5,cv2.GC_INIT_WITH_RECT)

mask2 = np.where((mask==2)|(mask==0),0,1).astype('uint8')
img1 = img*mask2[:,:,np.newaxis]
cv2_imshow(img1)
# Out:
# <PIL.Image.Image image mode=RGB size=480x376 at 0x7F434A897908>

# %% [markdown]
# # IMAGE 4

# %%
img = images[3].copy()

cv2.rectangle(img, (130, 30), (400, 500), (255, 0, 0), 2)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=480x319 at 0x7F434C148400>

# %%
img = images[3].copy()
mask = np.zeros(img.shape[:2],np.uint8)

bgdModel = np.zeros((1,65),np.float64)

fgdModel = np.zeros((1,65),np.float64)

rect = (130, 30, 400, 500)
cv2.grabCut(img,mask,rect,bgdModel,fgdModel,5,cv2.GC_INIT_WITH_RECT)

mask2 = np.where((mask==2)|(mask==0),0,1).astype('uint8')
img1 = img*mask2[:,:,np.newaxis]
cv2_imshow(img1)
# Out:
# <PIL.Image.Image image mode=RGB size=480x319 at 0x7F434A89DA90>

# %% [markdown]
# # IMAGE 5

# %%
img = images[4].copy()

cv2.rectangle(img, (130, 30), (400, 500), (255, 0, 0), 2)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=480x320 at 0x7F434C148BA8>

# %%
img = images[4].copy()
mask = np.zeros(img.shape[:2],np.uint8)

bgdModel = np.zeros((1,65),np.float64)

fgdModel = np.zeros((1,65),np.float64)

rect = (130, 20, 400, 500)
cv2.grabCut(img,mask,rect,bgdModel,fgdModel,5,cv2.GC_INIT_WITH_RECT)

mask2 = np.where((mask==2)|(mask==0),0,1).astype('uint8')
img1 = img*mask2[:,:,np.newaxis]
cv2_imshow(img1)
# Out:
# <PIL.Image.Image image mode=RGB size=480x320 at 0x7F434A897B00>

# %% [markdown]
# # IMAGE 6 (Need FIX)

# %%
img = images[5].copy()

cv2.rectangle(img, (60, 80), (240, 450), (255, 0, 0), 2)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=319x480 at 0x7F434C1487F0>

# %%
img = images[5].copy()
mask = np.zeros(img.shape[:2],np.uint8)

bgdModel = np.zeros((1,65),np.float64)

fgdModel = np.zeros((1,65),np.float64)

rect = (60, 80, 240, 450)
cv2.grabCut(img,mask,rect,bgdModel,fgdModel,5,cv2.GC_INIT_WITH_RECT)

mask2 = np.where((mask==2)|(mask==0),0,1).astype('uint8')
img1 = img*mask2[:,:,np.newaxis]
cv2_imshow(img1)
# Out:
# <PIL.Image.Image image mode=RGB size=319x480 at 0x7F434A8A3DD8>
